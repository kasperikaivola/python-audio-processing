# %%
import os
from IPython.display import Image, display

# %%
# %run beampattern.py 1 0.0425
# %run beampattern.py 2 0.0425
# %run beampattern.py 1 0.2
# %run beampattern.py 2 0.2

# %%
# Get list of all files in the current directory
files_in_directory = os.listdir('.')

# Filter out only the .png files
png_files = [f for f in files_in_directory if (f.endswith('.png') and "directivity" in f) ]

# Display each .png file
for png_file in png_files:
    display(Image(filename=png_file, width=500))

# %%
# %run arraygain.py 1 0.0425
# %run arraygain.py 2 0.0425
# %run arraygain.py 1 0.2
# %run arraygain.py 2 0.2
# Out:
# C:\Users\kaspe\OneDrive - Aalto University\RWTH\Courses\61.00004 Audio Processing Using Python\code prerequisites-20240421\prerequisites\08_beamformer\arraygain.py:62: ComplexWarning: Casting complex values to real discards the imaginary part
#   E[:, f] = np.exp(-1j * 2 * np.pi * freqs[f] * dist / c * np.cos(theta_0))  # Array steering vector
# C:\Users\kaspe\OneDrive - Aalto University\RWTH\Courses\61.00004 Audio Processing Using Python\code prerequisites-20240421\prerequisites\08_beamformer\arraygain.py:85: RuntimeWarning: divide by zero encountered in scalar divide
#   f_aliasing = c/d*1/(1+np.cos(theta_0))
# C:\Users\kaspe\OneDrive - Aalto University\RWTH\Courses\61.00004 Audio Processing Using Python\code prerequisites-20240421\prerequisites\08_beamformer\arraygain.py:62: ComplexWarning: Casting complex values to real discards the imaginary part
#   E[:, f] = np.exp(-1j * 2 * np.pi * freqs[f] * dist / c * np.cos(theta_0))  # Array steering vector
# C:\Users\kaspe\OneDrive - Aalto University\RWTH\Courses\61.00004 Audio Processing Using Python\code prerequisites-20240421\prerequisites\08_beamformer\arraygain.py:62: ComplexWarning: Casting complex values to real discards the imaginary part
#   E[:, f] = np.exp(-1j * 2 * np.pi * freqs[f] * dist / c * np.cos(theta_0))  # Array steering vector
# C:\Users\kaspe\OneDrive - Aalto University\RWTH\Courses\61.00004 Audio Processing Using Python\code prerequisites-20240421\prerequisites\08_beamformer\arraygain.py:85: RuntimeWarning: divide by zero encountered in scalar divide
#   f_aliasing = c/d*1/(1+np.cos(theta_0))
# C:\Users\kaspe\OneDrive - Aalto University\RWTH\Courses\61.00004 Audio Processing Using Python\code prerequisites-20240421\prerequisites\08_beamformer\arraygain.py:62: ComplexWarning: Casting complex values to real discards the imaginary part
#   E[:, f] = np.exp(-1j * 2 * np.pi * freqs[f] * dist / c * np.cos(theta_0))  # Array steering vector

# %%
# Get list of all files in the current directory
files_in_directory = os.listdir('.')

# Filter out only the .png files
png_files = [f for f in files_in_directory if (f.endswith('.png') and "arraygain" in f) ]

# Display each .png file
for png_file in png_files:
    display(Image(filename=png_file, width=500))
