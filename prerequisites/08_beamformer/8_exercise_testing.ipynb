# %%
import os
from IPython.display import Image, display

# %%
# %run beampattern.py 1 0.0425
# %run beampattern.py 2 0.0425
# %run beampattern.py 1 0.2
# %run beampattern.py 2 0.2

# %%
# Get list of all files in the current directory
files_in_directory = os.listdir('.')

# Filter out only the .png files
png_files = [f for f in files_in_directory if (f.endswith('.png') and "directivity" in f) ]

# Display each .png file
for png_file in png_files:
    display(Image(filename=png_file, width=500))

# %%
# %run arraygain.py 1 0.0425
# %run arraygain.py 2 0.0425
# %run arraygain.py 1 0.2
# %run arraygain.py 2 0.2
# Out:
# B.shape  (8, 256)
# bf2:  128
# Psi_diff.shape:  (128,)
# Psi_wn.shape:  (128,)
# (8, 256) (256, 8) (128,) (128,)
# c:\Users\kaspe\OneDrive - Aalto University\RWTH\Courses\61.00004 Audio Processing Using Python\code prerequisites-20240421\venv\lib\site-packages\matplotlib\cbook.py:1699: ComplexWarning: Casting complex values to real discards the imaginary part
#   return math.isfinite(val)
# c:\Users\kaspe\OneDrive - Aalto University\RWTH\Courses\61.00004 Audio Processing Using Python\code prerequisites-20240421\venv\lib\site-packages\matplotlib\cbook.py:1345: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
# B.shape  (8, 256)
# bf2:  128
# Psi_diff.shape:  (128,)
# Psi_wn.shape:  (128,)
# (8, 256) (256, 8) (128,) (128,)
# B.shape  (8, 256)
# bf2:  128
# Psi_diff.shape:  (128,)
# Psi_wn.shape:  (128,)
# (8, 256) (256, 8) (128,) (128,)
# B.shape  (8, 256)
# bf2:  128
# Psi_diff.shape:  (128,)
# Psi_wn.shape:  (128,)
# ...

# %%
# Get list of all files in the current directory
files_in_directory = os.listdir('.')

# Filter out only the .png files
png_files = [f for f in files_in_directory if (f.endswith('.png') and "arraygain" in f) ]

# Display each .png file
for png_file in png_files:
    display(Image(filename=png_file, width=500))
